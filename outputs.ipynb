# %% [markdown]
# #ÇIKTILAR

# %% [markdown]
# ##Kumanda sınıfı 3 fonskiyon çıktıları

# %% [markdown]
# altyazi çıktısı

# %% [markdown]
# ![altyazi_durumu.png](data:image/png;base64,...)

# %% [markdown]
# renk ayarı çıktısı

# %% [markdown]
# ![Renk_ayari.png](data:image/png;base64,...)

# %% [markdown]
# hoparlor bilgileri çıktısı

# %% [markdown]
# ![hoparlor_bilgileri.png](data:image/png;base64,...)

# %% [markdown]
# ##PC_Lab çıktıları

# %% [markdown]
# Öğrenci Bilgileri

# %% [markdown]
# ![ogrenci_bilgileri.png](data:image/png;base64,...)

# %% [markdown]
# Boş masa bilgileri

# %% [markdown]
# ![bos_bilgisayar_sayisi.png](data:image/png;base64,...)

# %% [markdown]
# Öğretmen Bilgileri

# %% [markdown]
# ![hoca.png](data:image/png;base64,...)

# %% [markdown]
# Öğrenci Değişim durumu

# %% [markdown]
# ![ogrenci_degisimi.png](data:image/png;base64,...)

# %% [markdown]
# ##Hayvan sınıfı çıktıları

# %% [markdown]
# ![hayvan.png](data:image/png;base64,...)
